# %% [markdown]
# <a href="https://colab.research.google.com/github/ashraf109/BBP01-107-DataAnalyzeAndVisualize/blob/main/BBP01_107_DataAnalyzeAndVisualize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !wget https://raw.githubusercontent.com/Abdullahfoysal/pp11-Project-AnalyzeAndVisualize/refs/heads/main/student_data.csv
# Out:
# --2024-12-21 02:46:48--  https://raw.githubusercontent.com/Abdullahfoysal/pp11-Project-AnalyzeAndVisualize/refs/heads/main/student_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 133023 (130K) [text/plain]
# Saving to: ‘student_data.csv’
#
# student_data.csv    100%[===================>] 129.91K  --.-KB/s    in 0.01s
#
# 2024-12-21 02:46:49 (11.5 MB/s) - ‘student_data.csv’ saved [133023/133023]

# %%
df=pd.read_csv("student_data.csv")
print(df)
filtered=df[(df["ssc_gpa"]>4) & (df["hsc_gpa"]>4)]
print("The number of the students who have completed both:",filtered)
# Out:
#        id first_name   last_name                        email      gender  \
# 0       1     Fraser   Petschelt   fpetschelt0@craigslist.org        Male
# 1       2         Si     Skottle    sskottle1@squarespace.com        Male
# 2       3      Barbi   Seedhouse  bseedhouse2@miibeian.gov.cn      Female
# 3       4     Shadow      Scarff         sscarff3@walmart.com        Male
# 4       5      Karim  Domenicone    kdomenicone4@sakura.ne.jp        Male
# ..    ...        ...         ...                          ...         ...
# 995   996  Catharina     Bradtke       cbradtkern@pcworld.com      Female
# 996   997  Anastasia       Lowde            alowdero@blog.com      Female
# 997   998      Tandi    Whitlock      twhitlockrp@skyrock.com      Female
# 998   999    Malvina        Tuhy        mtuhyrq@bloglines.com  Non-binary
# 999  1000     Kissee    Okeshott          kokeshottrr@msu.edu      Female
#
#           ip_address  cgpa  passing_year        department  attendance  \
# ...

# %%
display_abroad_canada=df[df["study_abroad_country"]=="Canada"]
print(display_abroad_canada)
# Out:
#       id first_name last_name                         email       gender  \
# 18    19    Allegra   Comport             acomporti@mapy.cz       Female
# 240  241       Bank  Roggieri  broggieri6o@businesswire.com         Male
# 404  405    Sergent   Droogan         sdrooganb8@reddit.com         Male
# 468  469     Andris     Neary     anearyd0@odnoklassniki.ru         Male
# 470  471     Terrye   Bointon   tbointond2@surveymonkey.com       Female
# 489  490    Freemon    Latter             flatterdl@ask.com         Male
# 590  591      Annie      Gunn             agunnge@webmd.com       Female
# 679  680    Jacquie    Sproul           jsprouliv@desdev.cn  Genderqueer
# 701  702       Kaja    Sidary           ksidaryjh@wikia.com       Female
# 883  884    Barclay   Reimers        breimersoj@nbcnews.com         Male
# 889  890       Pooh     Arpur        parpurop@geocities.com       Female
#
#           ip_address  cgpa  passing_year        department  attendance  \
# ...
